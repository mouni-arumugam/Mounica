# %% [markdown]
# <a href="https://colab.research.google.com/github/mouni-arumugam/Mounica/blob/main/Mvit_Batch_3_%7C%7C_AI%26ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Day 1 - basic

# %%
Name = "Mounica"
Lastname = "A"
print(Name)
print(Lastname)
print(type(Name))
print(type(Lastname))
# Out:
# Mounica
# A
# <class 'str'>
# <class 'str'>
